# %% [markdown]
# <a href="https://colab.research.google.com/github/MichealOmojola/Neptune-AI-Projects/blob/main/machine_learning/neptune_ai/Micheal_UCI_Heart_Disease_neptune_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Original Data Source Link:
# https://archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# CSV Formatted Dataset:
# https://www.kaggle.com/ronitf/heart-disease-uci?select=heart.csv

# %% [markdown]
# The dataset has 14 key attributes out of original 76, from the dataset along with their descriptions:

# %% [markdown]
# - age: The person’s age in years
# - sex: The person’s sex (1 = male, 0 = female)
# - cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical - angina, Value 3: non-anginal pain, Value 4: asymptomatic)
# - trestbps: The person’s resting blood pressure
# - chol: The person’s cholesterol measurement in mg/dl
# - fbs: The person’s fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
# - restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes’ criteria)
# - thalach: The person’s maximum heart rate achieved
# - exang: Exercise induced angina (1 = yes; 0 = no)
# - oldpeak: ST depression induced by exercise relative to rest (‘ST’ relates to positions on the ECG plot)
# - slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
# - ca: The number of major vessels (0–3)
# - thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
# - target: Heart disease (0 = no, 1 = yes)

# %% [markdown]
# Note: Make sure you have download the dataset from Kaggle link first.
#
# - Now we will upload the heart.csv from local file system to Google colab
# server.
# - You can also use pandas to upload the file from local file system also
#   - df = pd.read_csv(io.BytesIO(uploaded['heart.csv']))

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
# !pip install neptune-client neptune-tensorflow-keras
# Out:
# Requirement already satisfied: neptune-client in /usr/local/lib/python3.10/dist-packages (1.8.6)
# Requirement already satisfied: neptune-tensorflow-keras in /usr/local/lib/python3.10/dist-packages (2.2.0)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (3.1.41)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (9.4.0)
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from neptune-client) (2.3.0)
# Requirement already satisfied: boto3>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (1.34.23)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (11.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (8.1.7)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (0.18.3)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from neptune-client) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neptune-client) (1.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from neptune-client) (5.9.5)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (2.31.0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (1.3.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (1.16.0)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (3.0.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (2.0.7)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client) (1.7.0)
# Requirement already satisfied: tensorflow>2.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune-tensorflow-keras) (2.15.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.23 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client) (1.34.23)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client) (0.10.0)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (6.1.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (1.0.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (6.0.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (3.19.2)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (1.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client) (4.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython>=2.0.8->neptune-client) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client) (2023.11.17)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from swagger-spec-validator>=2.7.4->neptune-client) (4.19.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>2.0.0->neptune-tensorflow-keras) (2.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune-client) (2023.3.post1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>2.0.0->neptune-tensorflow-keras) (0.42.0)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.10/dist-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune-client) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune-client) (5.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (3.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (4.9)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (2.4)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (0.1.1)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>2.0.0->neptune-tensorflow-keras) (0.5.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema->swagger-spec-validator>=2.7.4->neptune-client) (2.8.19.20240106)

# %%
# !pip install neptune-notebooks
# Out:
# Requirement already satisfied: neptune-notebooks in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from neptune-notebooks) (8.1.7)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from neptune-notebooks) (0.18.3)
# Requirement already satisfied: neptune-client>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from neptune-notebooks) (1.8.6)
# Requirement already satisfied: notebook>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from neptune-notebooks) (6.5.5)
# Requirement already satisfied: path.py in /usr/local/lib/python3.10/dist-packages (from neptune-notebooks) (12.5.0)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (3.1.41)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (9.4.0)
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (2.3.0)
# Requirement already satisfied: boto3>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (1.34.23)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (11.0.3)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (3.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (1.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (5.9.5)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (2.31.0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (1.3.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (1.16.0)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (3.0.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (2.0.7)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/local/lib/python3.10/dist-packages (from neptune-client>=0.9.0->neptune-notebooks) (1.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (3.1.3)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (6.3.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (5.7.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (1.5.9)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (5.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.3.0->neptune-notebooks) (1.0.0)
# Requirement already satisfied: path in /usr/local/lib/python3.10/dist-packages (from path.py->neptune-notebooks) (16.9.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.23 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client>=0.9.0->neptune-notebooks) (1.34.23)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client>=0.9.0->neptune-notebooks) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3>=1.16.0->neptune-client>=0.9.0->neptune-notebooks) (0.10.0)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (6.1.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (1.0.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (6.0.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (3.19.2)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (1.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (4.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython>=2.0.8->neptune-client>=0.9.0->neptune-notebooks) (4.0.11)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.3.0->neptune-notebooks) (4.1.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.3.0->neptune-notebooks) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.3.0->neptune-notebooks) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (2.16.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.3.0->neptune-notebooks) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.3.0->neptune-notebooks) (4.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client>=0.9.0->neptune-notebooks) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client>=0.9.0->neptune-notebooks) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20.0->neptune-client>=0.9.0->neptune-notebooks) (2023.11.17)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook>=4.3.0->neptune-notebooks) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.3.0->neptune-notebooks) (21.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->notebook>=4.3.0->neptune-notebooks) (7.34.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune-client>=0.9.0->neptune-notebooks) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->neptune-client>=0.9.0->neptune-notebooks) (1.23.5)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.10/dist-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune-client>=0.9.0->neptune-notebooks) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune-client>=0.9.0->neptune-notebooks) (5.0.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (3.0.43)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.3.0->neptune-notebooks) (3.7.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.3.0->neptune-notebooks) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.3.0->neptune-notebooks) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.3.0->neptune-notebooks) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.3.0->neptune-notebooks) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.3.0->neptune-notebooks) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.8.3)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (2.4)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (0.1.1)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (1.13)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=4.3.0->neptune-notebooks) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.10/dist-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat->notebook>=4.3.0->neptune-notebooks) (2.8.19.20240106)

# %%
# !jupyter nbextension enable --py neptune-notebooks
# Out:
# Enabling notebook extension neptune-notebooks/neptune-notebook...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json

# %%
# !pip show neptune-client
# Out:
# Name: neptune-client
# Version: 1.8.6
# Summary: Neptune Client
# Home-page: https://neptune.ai/
# Author: neptune.ai
# Author-email: contact@neptune.ai
# License: Apache-2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: boto3, bravado, click, future, GitPython, oauthlib, packaging, pandas, Pillow, psutil, PyJWT, requests, requests-oauthlib, six, swagger-spec-validator, urllib3, websocket-client
# Required-by: neptune-notebooks

# %%
# !pip show neptune-tensorflow-keras
# Out:
# Name: neptune-tensorflow-keras
# Version: 2.2.0
# Summary: Neptune.ai tensorflow-keras integration library
# Home-page: https://neptune.ai/
# Author: neptune.ai
# Author-email: contact@neptune.ai
# License: Apache-2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: tensorflow
# Required-by:

# %%
# !ls -l

# %%
# import neptune.new as neptune
# from neptune.new.integrations.tensorflow_keras import NeptuneCallback

# %%
import neptune
from neptune.integrations.tensorflow_keras import NeptuneCallback

# %%
import pandas as pd
import seaborn as  sns
import matplotlib.pyplot as plt

# %%
run = neptune.init_run(
    project="micheal1234/Keras-heart-disease",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3ZmRlZGMyOS1kNmUyLTQwN2YtYTEyNi01ZDJmODAxZTA3NjYifQ==",
)  # your credentials
# Out:
# https://app.neptune.ai/micheal1234/Keras-heart-disease/e/KHD-4

# %%
model = neptune.init_model(
    name="Prediction model",
    key="MOD",
    project="micheal1234/Keras-heart-disease",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3ZmRlZGMyOS1kNmUyLTQwN2YtYTEyNi01ZDJmODAxZTA3NjYifQ==", # your credentials
)
# Out:
# ---------------------------------------------------------------------------
# HTTPConflict                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/hosted_neptune_backend.py in _create_experiment(self, project_id, parent_id, container_type, additional_params)
#     406         try:
# --> 407             experiment = self.leaderboard_client.api.createExperiment(**kwargs).response().result
#     408             return ApiExperiment.from_experiment(experiment)
#
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/swagger_client_wrapper.py in __call__(self, *args, **kwargs)
#     112         except HTTPError as e:
# --> 113             self.handle_neptune_http_errors(e.response, exception=e)
#     114
#
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/swagger_client_wrapper.py in handle_neptune_http_errors(response, exception)
#     105         if exception:
# --> 106             raise exception
#     107
#
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/swagger_client_wrapper.py in __call__(self, *args, **kwargs)
#     110             future = self._api_method(*args, **kwargs)
# --> 111             return FinishedApiResponseFuture(future.response())  # wait synchronously
#     112         except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/bravado/http_future.py in response(self, timeout, fallback_result, exceptions_to_catch)
#     199
# --> 200             swagger_result = self._get_swagger_result(incoming_response)
#     201
#
# /usr/local/lib/python3.10/dist-packages/bravado/http_future.py in wrapper(self, *args, **kwargs)
#     123         try:
# --> 124             return func(self, *args, **kwargs)
#     125         except connection_errors as exception:
#
# /usr/local/lib/python3.10/dist-packages/bravado/http_future.py in _get_swagger_result(self, incoming_response)
#     299         if self.operation is not None:
# --> 300             unmarshal_response(
#     301                 incoming_response,
#
# /usr/local/lib/python3.10/dist-packages/bravado/http_future.py in unmarshal_response(incoming_response, operation, response_callbacks)
#     352
# --> 353     raise_on_expected(incoming_response)
#     354
#
# /usr/local/lib/python3.10/dist-packages/bravado/http_future.py in raise_on_expected(http_response)
#     419     if not 200 <= http_response.status_code < 300:
# --> 420         raise make_http_exception(
#     421             response=http_response,
#
# HTTPConflict: 409 Conflict
#
# The above exception was the direct cause of the following exception:
#
# NeptuneObjectCreationConflict             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/neptune/metadata_containers/model.py in _get_or_create_api_object(self)
#     224             try:
# --> 225                 return self._backend.create_model(project_id=self._project_api_object.id, key=self._key)
#     226             except NeptuneObjectCreationConflict as e:
#
# /usr/local/lib/python3.10/dist-packages/neptune/common/backends/utils.py in wrapper(*args, **kwargs)
#      75             try:
# ---> 76                 return func(*args, **kwargs)
#      77             except requests.exceptions.InvalidHeader as e:
#
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/hosted_neptune_backend.py in create_model(self, project_id, key)
#     366
# --> 367         return self._create_experiment(
#     368             project_id=project_id,
#
# /usr/local/lib/python3.10/dist-packages/neptune/internal/backends/hosted_neptune_backend.py in _create_experiment(self, project_id, parent_id, container_type, additional_params)
#     411         except HTTPConflict as e:
# --> 412             raise NeptuneObjectCreationConflict() from e
#     413
#
# NeptuneObjectCreationConflict:
#
# The above exception was the direct cause of the following exception:
#
# NeptuneModelKeyAlreadyExistsError         Traceback (most recent call last)
# <ipython-input-124-4d369bf1eb32> in <cell line: 1>()
# ----> 1 model = neptune.init_model(
#       2     name="Prediction model",
#       3     key="MOD",
#       4     project="micheal1234/Keras-heart-disease",
#       5     api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3ZmRlZGMyOS1kNmUyLTQwN2YtYTEyNi01ZDJmODAxZTA3NjYifQ==", # your credentials
#
# /usr/local/lib/python3.10/dist-packages/neptune/metadata_containers/model.py in __init__(self, with_id, name, key, project, api_token, mode, flush_period, proxies, async_lag_callback, async_lag_threshold, async_no_progress_callback, async_no_progress_threshold)
#     194             project = OFFLINE_PROJECT_QUALIFIED_NAME
#     195
# --> 196         super().__init__(
#     197             project=project,
#     198             api_token=api_token,
#
# /usr/local/lib/python3.10/dist-packages/neptune/metadata_containers/metadata_container.py in __init__(self, project, api_token, mode, flush_period, proxies, async_lag_callback, async_lag_threshold, async_no_progress_callback, async_no_progress_threshold)
#     155         self._project_id: UniqueId = self._project_api_object.id
#     156
# --> 157         self._api_object: ApiExperiment = self._get_or_create_api_object()
#     158         self._id: UniqueId = self._api_object.id
#     159         self._sys_id: SysId = self._api_object.sys_id
#
# /usr/local/lib/python3.10/dist-packages/neptune/metadata_containers/model.py in _get_or_create_api_object(self)
#     226             except NeptuneObjectCreationConflict as e:
#     227                 base_url = self._backend.get_display_address()
# --> 228                 raise NeptuneModelKeyAlreadyExistsError(
#     229                     model_key=self._key,
#     230                     models_tab_url=f"{base_url}/{project_workspace}/{project_name}/models",
#
# NeptuneModelKeyAlreadyExistsError:
#
# ----NeptuneModelKeyAlreadyExistsError---------------------------------------------------
#
# A model with the provided key (MOD) already exists in this project.
#
# You can check all of your models in the Models section of the project:
# https://app.neptune.ai/micheal1234/Keras-heart-disease/models
#
# Note: If there is a model with the same key in the trash, you need to delete the model from the trash to make the key
# available again.
#
# Need help?-> https://docs.neptune.ai/getting_help

# %%
model_version = neptune.init_model_version(
    model="KHD-MOD",
    project="micheal1234/Keras-heart-disease",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3ZmRlZGMyOS1kNmUyLTQwN2YtYTEyNi01ZDJmODAxZTA3NjYifQ==", # your credentials
)
# Out:
# https://app.neptune.ai/micheal1234/Keras-heart-disease/m/KHD-MOD/v/KHD-MOD-3

# %%
import io
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1        0      150      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0        1      187      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0        0      172      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0        1      178      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0        1      163      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0        1      123      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0        1      132      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1        1      141      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0        1      115      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0        0      174      0      0.0      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.shape
# Out:
# (303, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
f = sns.countplot(x='target', data=df)
f.set_title("Heart disease distribution (Target distribution)")
f.set_xticklabels(['Heart disease - Yes', 'Heart Disease - No'])
plt.xlabel("");
# Out:
# <ipython-input-130-57c137459730>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   f.set_xticklabels(['Heart disease - Yes', 'Heart Disease - No'])

# %%
f = sns.countplot(x='target', data=df, hue='sex')
plt.legend(['Female', 'Male'])
f.set_title("Heart Disease by gender")
f.set_xticklabels(['Heart disease - Yes', 'Heart Disease - No'])
plt.xlabel("");
# Out:
# <ipython-input-131-316d3cfac918>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   f.set_xticklabels(['Heart disease - Yes', 'Heart Disease - No'])

# %%
heat_map = sns.heatmap(df.corr(method='pearson'), annot=True, fmt='.2f', linewidths=2)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=45);
plt.rcParams["figure.figsize"] = (50,50)

# %% [markdown]
# Now we need to split the dataset into target and training format.
# - Target will have only target column
# - Training data will have all the columns besides target column

# %%
df_input = pd.DataFrame(df.iloc[:, 0:13])

# %%
df_input.shape
# Out:
# (303, 13)

# %%
df_input
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal
# 0     63    1   3       145   233    1        0      150      0      2.3      0   0     1
# 1     37    1   2       130   250    0        1      187      0      3.5      0   0     2
# 2     41    0   1       130   204    0        0      172      0      1.4      2   0     2
# 3     56    1   1       120   236    0        1      178      0      0.8      2   0     2
# 4     57    0   0       120   354    0        1      163      1      0.6      2   0     2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...    ...  ..   ...
# 298   57    0   0       140   241    0        1      123      1      0.2      1   0     3
# 299   45    1   3       110   264    0        1      132      0      1.2      1   0     3
# 300   68    1   0       144   193    1        1      141      0      3.4      1   2     3
# 301   57    1   0       130   131    0        1      115      1      1.2      1   1     3
# 302   57    0   1       130   236    0        0      174      0      0.0      1   1     2
#
# [303 rows x 13 columns]

# %%
df_target = pd.DataFrame(df.iloc[:, 13],columns=['target'])

# %%
df_target.shape
# Out:
# (303, 1)

# %%
df_target
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [303 rows x 1 columns]

# %% [markdown]
# Transforming the training data so it can be understood by the deep learning engine.
#
# - StandardScaler removes the mean and scales the data to unit variance.
#
# More info:
# - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# - https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html#sphx-glr-auto-examples-preprocessing-plot-all-scaling-py

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled_input = scaler.fit_transform(df_input)

# %%
df_scaled_input
# Out:
# array([[ 0.9521966 ,  0.68100522,  1.97312292, ..., -2.27457861,
#         -0.71442887, -2.14887271],
#        [-1.91531289,  0.68100522,  1.00257707, ..., -2.27457861,
#         -0.71442887, -0.51292188],
#        [-1.47415758, -1.46841752,  0.03203122, ...,  0.97635214,
#         -0.71442887, -0.51292188],
#        ...,
#        [ 1.50364073,  0.68100522, -0.93851463, ..., -0.64911323,
#          1.24459328,  1.12302895],
#        [ 0.29046364,  0.68100522, -0.93851463, ..., -0.64911323,
#          0.26508221,  1.12302895],
#        [ 0.29046364, -1.46841752,  0.03203122, ..., -0.64911323,
#          0.26508221, -0.51292188]])

# %% [markdown]
# - Splitting the dataset into two sets:
#   - training set
#   - testing set.
# - Library Used:
#    - scikit-learn library has been used with function sklearn.model_selection.train_test_split() function to split the source data

# %%
from sklearn.model_selection import train_test_split
df_input_train, df_input_test, df_target_train, df_target_test = train_test_split(df_scaled_input, df_target, test_size = 0.30, random_state = 5)
print("Training data Split (Train & Test)")
print(df_input_train.shape)
print(df_input_test.shape)

print("Target data Split (Train & Test)")
print(df_target_train.shape)
print(df_target_test.shape)
# Out:
# Training data Split (Train & Test)
# (212, 13)
# (91, 13)
# Target data Split (Train & Test)
# (212, 1)
# (91, 1)

# %% [markdown]
# **Build the Keras classifier to predict the heart disease**

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# **Keras Settings:**
#
# - In the first line, we se the model as Sequential.
# - All Layers
#   - Added 3 fully connected Dense layers, two hidden and one output.
#   - All layers are from Dense class.
# - First Layer (Dense(30, input_dim=13, activation='tanh'))
#   - The first input layer has inout dimension as 13 for all 13 columns.
#   - the activation function is tanh
# - Second Layer (Dense(20, activation='tanh'))
#   - It has 20 neurons and the tanh activation function.
# - Output Layer (Dense(1, activation='sigmoid'))
#   - Output layer has a single neuron (output)
#   - The sigmoid activation function is selected for binary classification problems
#   - Out target data is binay - Yes or No heart disease .

# %%
model = Sequential()
model.add(Dense(30, input_dim=13, activation='tanh'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Compile and fit Step:**
#
# Compile function has 3 arguments:
# - The adam optimizer: An algorithm for first-order gradient-based optimization.
# - The binary_crossentropy loss function: logarithmic loss, which for a binary classification problem is defined in Keras as binary_crossentropy
# - The accuracy metric: to evaluate the performance of your model during training and testing
#
# Fit Function has the following parameters:
# - epochs = 100

# %% [markdown]
# **Plotting Keras Model**
# - https://keras.io/api/utils/model_plotting_utils/

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
from keras.utils import plot_model

# %%
# from keras.utils.vis_utils import plot_model

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
params = {"learning_rate": 0.001, "momentum": 0.5, "epochs": 150, "batch_size": 32, "optimizer": "Adam"}
run["parameters"] = params

# %%
import tensorflow as tf

# %%
optimizer = tf.keras.optimizers.Adam(
    learning_rate = params["learning_rate"],
)

# %%
neptune_cbk = NeptuneCallback(run=run, base_namespace="training")

# %%
for epoch in range(10):
    run["train/loss"].append(0.9 ** epoch)

run["eval/f1_score"] = 0.66

# %%
model.compile(
    optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"]
)

# %%
history = model.fit(
    df_input_train,
    df_target_train,
    epochs=params["epochs"],
    batch_size=params["batch_size"],
    callbacks=[neptune_cbk],
    verbose = 1
)

# %%
eval_metrics = model.evaluate(df_input_test, df_target_test, verbose = 0)

# %%
for j, metric in enumerate(eval_metrics):
  run["eval/{}".format(model.metrics_names[j])] = metric

# %%
model.summary()
score = model.evaluate(df_input_test, df_target_test, verbose = 0)
print("model Accuracy = ", score[1])

# %%
history

# %%
history.history.keys()

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
acc = history.history['accuracy']
loss = history.history['loss']

# %%
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label='Accuracy', color="green")
plt.plot(epochs, loss, 'b', label='Loss', color="red")
plt.title('Accuracy & Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy & Loss')
plt.legend()


plt.show()

# %%
from sklearn.metrics import confusion_matrix

# %%
Target_Classification = model.predict(df_input_test)
Target_Classification = (Target_Classification > 0.5)





print(confusion_matrix(df_target_test, Target_Classification))

# %%
import numpy as np
best_model_accuracy = history.history['accuracy'][np.argmin(history.history['loss'])]
print(best_model_accuracy)

# %%
model.save('model/keras-heart-disease.h5')

# %%
# !ls -l model

# %%
from tensorflow import keras

# %%
model_x = keras.models.load_model('model/keras-heart-disease.h5')

# %%
print(model_x.metrics[0])
print(model_x.metrics[1])

# %%
model_x.summary()

# %%
model_version["model"].upload('model/keras-heart-disease.h5')

# %%
model_version.change_stage("staging")

# %%
# help(model)

# %%
# Log the model
run["model"].upload('model/keras-heart-disease.h5')

# %%
# model['model'].upload('model/keras-heart-disease.bin')

# %%
# model['model'].upload('model/keras-heart-disease.bin')

# %%
# !ls

# %%
run["data/network_plot"].upload('model_plot.png')

# %%
model_version.stop()

# %%
run.stop()
